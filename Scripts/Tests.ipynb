# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define path
path = r'/Users/elisabetta/Documents/12-2022 Instacart Basket Analysis'

# %%
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled_V3.csv'))
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked_V3.csv'))
df_deps = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled_V3.csv'))

# %%
df_merged.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  price _merge
# ...

# %%
df_ords.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  price
# 0             19    5.8
# 1             13    9.3
# 2              7    4.5
# 3              1   10.5
# 4             13    4.3

# %%
df_deps.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
