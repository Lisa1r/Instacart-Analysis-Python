# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing and analyzing data

# %%
# Define path
path = r'/Users/elisabetta/Documents/12-2022 Instacart Basket Analysis'

# %%
df_ords_prods_merged_2 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
# Create subset not to run into memory issues
df = df_ords_prods_merged_2[:1000000]

# %%
# Check output
df.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  price price_range        busy_day  \
# 0         Soda        77              7    9.0      Medium  Regularly busy
# 1         Soda        77              7    9.0      Medium  Regularly busy
# 2         Soda        77              7    9.0      Medium  Regularly busy
# 3         Soda        77              7    9.0      Medium      Least busy
# 4         Soda        77              7    9.0      Medium      Least busy
#
#        busy_day_2 busiest_period_of_day
# 0  Regularly busy        Average orders
# 1      Least busy        Average orders
# 2      Least busy           Most orders
# 3      Least busy        Average orders
# 4      Least busy           Most orders

# %%
# Check output
df.shape
# Out:
# (1000000, 17)

# %%
# Group by product_name
df.groupby('product_name')

# %%
# Group by department_id
df.groupby('department_id')

# %%
# Aggregate using number_of_orders. This calculates the mean of the number of orders per department
df.groupby('department_id').agg({'number_of_orders' : ['mean']})
# Out:
#               number_of_orders
#                           mean
# department_id
# 4                    18.825780
# 7                    17.472355
# 13                   17.993423
# 14                   19.246334
# 16                   19.463012
# 17                   11.294069
# 19                   19.305237
# 20                   17.599636

# %%
# Alternative method to do same
df.groupby('department_id')['number_of_orders'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: number_of_orders, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'number_of_orders' : ['mean', 'min', 'max']})
# Out:
#               number_of_orders
#                           mean min max
# department_id
# 4                    18.825780   1  99
# 7                    17.472355   1  99
# 13                   17.993423   1  99
# 14                   19.246334   1  99
# 16                   19.463012   1  99
# 17                   11.294069   1  98
# 19                   19.305237   1  99
# 20                   17.599636   1  99

# %%
# Create column upon which flag will be based. Then assign it to customers WITHIN MAIN DATAFRAME df_ords_prods_merged_2

# %%
df_ords_prods_merged_2['max_number_of_orders'] = df_ords_prods_merged_2.groupby(['user_id'])['number_of_orders'].transform(np.max)

# %%
# Check output
df_ords_prods_merged_2.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  price price_range        busy_day  \
# 0         Soda        77              7    9.0      Medium  Regularly busy
# 1         Soda        77              7    9.0      Medium  Regularly busy
# 2         Soda        77              7    9.0      Medium  Regularly busy
# 3         Soda        77              7    9.0      Medium      Least busy
# 4         Soda        77              7    9.0      Medium      Least busy
#
#        busy_day_2 busiest_period_of_day  max_number_of_orders
# 0  Regularly busy        Average orders                    10
# 1      Least busy        Average orders                    10
# 2      Least busy           Most orders                    10
# 3      Least busy        Average orders                    10
# 4      Least busy           Most orders                    10

# %%
# NOTE. Function to remove limit on .head()
# pd.options.display.max_rows = None

# %%
# Create and assign values to loyalty flag by creating conditions using .loc()
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['max_number_of_orders'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged_2.loc[(df_ords_prods_merged_2['max_number_of_orders'] <= 40) & (df_ords_prods_merged_2['max_number_of_orders'] > 10) , 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['max_number_of_orders'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check output
df_ords_prods_merged_2['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# Check output CONTINUED
df_ords_prods_merged_2['max_number_of_orders']
# Out:
# 0           10
# 1           10
# 2           10
# 3           10
# 4           10
#             ..
# 32404854    31
# 32404855    31
# 32404856     3
# 32404857     3
# 32404858    16
# Name: max_number_of_orders, Length: 32404859, dtype: int64

# %%
df_ords_prods_merged_2[['user_id', 'loyalty_flag', 'max_number_of_orders']].head(60)
# Out:
#     user_id      loyalty_flag  max_number_of_orders
# 0         1      New customer                    10
# 1         1      New customer                    10
# 2         1      New customer                    10
# 3         1      New customer                    10
# 4         1      New customer                    10
# 5         1      New customer                    10
# 6         1      New customer                    10
# 7         1      New customer                    10
# 8         1      New customer                    10
# 9         1      New customer                    10
# 10       15  Regular customer                    22
# 11       15  Regular customer                    22
# 12       15  Regular customer                    22
# 13       15  Regular customer                    22
# 14       15  Regular customer                    22
# 15       19      New customer                     9
# 16       19      New customer                     9
# 17       19      New customer                     9
# 18       21  Regular customer                    33
# 19       31  Regular customer                    20
# 20       31  Regular customer                    20
# 21       43  Regular customer                    11
# 22       43  Regular customer                    11
# 23       52  Regular customer                    27
# 24       52  Regular customer                    27
# 25       52  Regular customer                    27
# 26       52  Regular customer                    27
# 27       52  Regular customer                    27
# 28       52  Regular customer                    27
# 29       52  Regular customer                    27
# 30       52  Regular customer                    27
# 31       52  Regular customer                    27
# 32       52  Regular customer                    27
# 33       52  Regular customer                    27
# 34       52  Regular customer                    27
# 35       52  Regular customer                    27
# 36       52  Regular customer                    27
# 37       67  Regular customer                    24
# 38       67  Regular customer                    24
# 39       67  Regular customer                    24
# 40       67  Regular customer                    24
# 41       67  Regular customer                    24
# 42       67  Regular customer                    24
# 43       67  Regular customer                    24
# 44       67  Regular customer                    24
# 45       67  Regular customer                    24
# 46       67  Regular customer                    24
# 47       67  Regular customer                    24
# 48       67  Regular customer                    24
# 49       67  Regular customer                    24
# 50       67  Regular customer                    24
# 51       67  Regular customer                    24
# 52       67  Regular customer                    24
# 53       67  Regular customer                    24
# 54       67  Regular customer                    24
# 55       67  Regular customer                    24
# 56       81      New customer                     7
# 57       81      New customer                     7
# 58       82  Regular customer                    19
# 59       82  Regular customer                    19

# %%
df_ords_prods_merged_2.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  price price_range        busy_day  \
# 0         Soda        77              7    9.0      Medium  Regularly busy
# 1         Soda        77              7    9.0      Medium  Regularly busy
# 2         Soda        77              7    9.0      Medium  Regularly busy
# 3         Soda        77              7    9.0      Medium      Least busy
# 4         Soda        77              7    9.0      Medium      Least busy
#
#        busy_day_2 busiest_period_of_day  max_number_of_orders  loyalty_flag
# 0  Regularly busy        Average orders                    10  New customer
# 1      Least busy        Average orders                    10  New customer
# 2      Least busy           Most orders                    10  New customer
# 3      Least busy        Average orders                    10  New customer
# 4      Least busy           Most orders                    10  New customer

# %% [markdown]
# # 03. Task 4.8 starts here

# %%
# STEP 2 Calculate the mean of the number of orders per department in actual dataframe
df_ords_prods_merged_2.groupby('department_id')

# %%
df_ords_prods_merged_2.groupby('department_id').agg({'number_of_orders' : ['mean']})
# Out:
#               number_of_orders
#                           mean
# department_id
# 1                    15.457838
# 2                    17.277920
# 3                    17.170395
# 4                    17.811403
# 5                    15.215751
# 6                    16.439806
# 7                    17.225802
# 8                    15.340650
# 9                    15.895474
# 10                   20.197148
# 11                   16.170638
# 12                   15.887671
# 13                   16.583536
# 14                   16.773669
# 15                   16.165037
# 16                   17.665606
# 17                   15.694469
# 18                   19.310397
# 19                   17.177343
# 20                   16.473447
# 21                   22.902379

# %%
# STEP 3 Analzye results and compare with subset results
# Here obviously all departments appear and also the means of departments are different (e.g. dept 4) because here all data is taken into account, not only a subset
# Most depts average between 15 and 17 orders with a couple of outliers, i.e. 10 (20 ords), 18 (19 ords), and 21 (22 ords)

# %%
# STEP 4 Already done above

# %%
# STEP 5 Determine spending stats per category of customer
# Loyal customers spend on average less than new and regular customers (10.4 vs 13.3 and 12.5 dollars). They hopefully compensate that by ordering more often
df_ords_prods_merged_2.groupby('loyalty_flag').agg({'price' : ['mean', 'min', 'max']})
# Out:
#                       price
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# STEP 6 Create spending flag per user based on average price across all their orders using given criteria
# First calculate average spend

# %%
df_ords_prods_merged_2['avg_spend'] = df_ords_prods_merged_2.groupby(['user_id'])['price'].transform(np.mean)

# %%
# STEP 6 CONTINUED Create spending flag and assign values to it using .loc()

# %%
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['avg_spend'] < 10, 'spend_flag'] = 'Low spender'

# %%
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['avg_spend'] >= 10, 'spend_flag'] = 'High spender'

# %%
# Check output
df_ords_prods_merged_2['spend_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spend_flag, dtype: int64

# %%
df_ords_prods_merged_2.head()
# Out:
#    order_id  user_id  number_of_orders  order_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                  2                  8
# 1   2398795        1                 2                  3                  7
# 2    473747        1                 3                  3                 12
# 3   2254736        1                 4                  4                  7
# 4    431534        1                 5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  price  price_range        busy_day  \
# 0         Soda  ...              7    9.0       Medium  Regularly busy
# 1         Soda  ...              7    9.0       Medium  Regularly busy
# 2         Soda  ...              7    9.0       Medium  Regularly busy
# 3         Soda  ...              7    9.0       Medium      Least busy
# 4         Soda  ...              7    9.0       Medium      Least busy
#
#        busy_day_2 busiest_period_of_day max_number_of_orders  loyalty_flag  \
# 0  Regularly busy        Average orders                   10  New customer
# 1      Least busy        Average orders                   10  New customer
# 2      Least busy           Most orders                   10  New customer
# 3      Least busy        Average orders                   10  New customer
# 4      Least busy           Most orders                   10  New customer
#
#   avg_spend   spend_flag
# 0  6.367797  Low spender
# 1  6.367797  Low spender
# 2  6.367797  Low spender
# 3  6.367797  Low spender
# 4  6.367797  Low spender
#
# [5 rows x 21 columns]

# %%
# STEP 7 Create frequency flag according to given criteria
# First calculate median of days_since_prior_order
df_ords_prods_merged_2['median_d_s_p_o'] = df_ords_prods_merged_2.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# STEP 7 CONTINUED Create frequency flag and assign values to it using .loc()

# %%
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['median_d_s_p_o'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merged_2.loc[(df_ords_prods_merged_2['median_d_s_p_o'] <= 20) & (df_ords_prods_merged_2['median_d_s_p_o'] > 10) , 'frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merged_2.loc[df_ords_prods_merged_2['median_d_s_p_o'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check output
df_ords_prods_merged_2['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
# Check output continued
df_ords_prods_merged_2['median_d_s_p_o'].isna().sum()
# Out:
# 5

# %%
# Check output. Why 5 values are NaN? Indeed, median is NULL
df_check = df_ords_prods_merged_2.loc[df_ords_prods_merged_2['median_d_s_p_o'].isna()]

# %%
df_check.head()
# Out:
#           order_id  user_id  number_of_orders  order_day_of_week  \
# 13645692    895835   159838                 1                  0
# 17251990    895835   159838                 1                  0
# 17622767    895835   159838                 1                  0
# 24138593    895835   159838                 1                  0
# 25880002    895835   159838                 1                  0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  price_range  \
# 13645692                            Organic Red Bell Pepper  ...       Medium
# 17251990                               Goat Cheese Crumbles  ...       Medium
# 17622767                           California Veggie Burger  ...          Low
# 24138593                              Organic Peeled Garlic  ...       Medium
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...          Low
#
#              busy_day    busy_day_2 busiest_period_of_day  \
# 13645692  Busiest day  Busiest days        Average orders
# 17251990  Busiest day  Busiest days        Average orders
# 17622767  Busiest day  Busiest days        Average orders
# 24138593  Busiest day  Busiest days        Average orders
# 25880002  Busiest day  Busiest days        Average orders
#
#          max_number_of_orders  loyalty_flag avg_spend   spend_flag  \
# 13645692                    1  New customer      7.42  Low spender
# 17251990                    1  New customer      7.42  Low spender
# 17622767                    1  New customer      7.42  Low spender
# 24138593                    1  New customer      7.42  Low spender
# 25880002                    1  New customer      7.42  Low spender
#
#          median_d_s_p_o  frequency_flag
# 13645692            NaN             NaN
# 17251990            NaN             NaN
# 17622767            NaN             NaN
# 24138593            NaN             NaN
# 25880002            NaN             NaN
#
# [5 rows x 23 columns]

# %%
df_check.shape
# Out:
# (5, 23)

# %%
df_check_2 = df_ords_prods_merged_2.loc[df_ords_prods_merged_2['days_since_prior_order'].isna()]

# %%
df_check_2.shape
# Out:
# (2076096, 23)

# %%
df_check_2.head(30)
# Out:
#      order_id  user_id  number_of_orders  order_day_of_week  \
# 0     2539329        1                 1                  2
# 23    2497897       52                 1                  1
# 37    3205960       67                 1                  3
# 58    1889835       82                 1                  3
# 75     520620      120                 1                  3
# 78    2040988      195                 1                  1
# 95    3226575      360                 1                  5
# 130   3371566      760                 1                  2
# 132    231498      793                 1                  1
# 140   2696986      991                 1                  3
# 155   3006945     1126                 1                  3
# 164   1345781     1131                 1                  4
# 174    512991     1256                 1                  1
# 197    378558     1434                 1                  6
# 238    316947     1540                 1                  1
# 261   2660971     1622                 1                  2
# 264   2460630     1641                 1                  0
# 271   2786460     1688                 1                  6
# 275   1244250     1755                 1                  1
# 289   1445157     1774                 1                  2
# 306   3292511     1998                 1                  5
# 307   1373167     2050                 1                  4
# 316    467519     2057                 1                  1
# 328     44909     2085                 1                  1
# 357    942901     2335                 1                  6
# 358    979563     2383                 1                  5
# 391   1077170     2387                 1                  2
# 443   3346493     2623                 1                  4
# 452    689851     2634                 1                  6
# 462    431881     2641                 1                  6
#
#      order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                    8                     NaN         196                  1
# 23                   9                     NaN         196                  4
# 37                  11                     NaN         196                  1
# 58                  15                     NaN         196                  6
# 75                  11                     NaN         196                  2
# 78                  14                     NaN         196                  2
# 95                  12                     NaN         196                  1
# 130                 11                     NaN         196                  2
# 132                 10                     NaN         196                  1
# 140                 16                     NaN         196                  1
# 155                 18                     NaN         196                  1
# 164                 14                     NaN         196                  2
# 174                 10                     NaN         196                 11
# 197                 19                     NaN         196                  7
# 238                 20                     NaN         196                 11
# 261                 16                     NaN         196                  5
# 264                 19                     NaN         196                 10
# 271                 12                     NaN         196                  2
# 275                 15                     NaN         196                  4
# 289                  9                     NaN         196                  1
# 306                 13                     NaN         196                 12
# 307                  9                     NaN         196                  3
# 316                  9                     NaN         196                  3
# 328                 13                     NaN         196                  3
# 357                 13                     NaN         196                 30
# 358                 17                     NaN         196                  8
# 391                 16                     NaN         196                  1
# 443                 14                     NaN         196                  2
# 452                 18                     NaN         196                  6
# 462                  1                     NaN         196                  1
#
#      reordered product_name  ...  price_range        busy_day      busy_day_2  \
# 0            0         Soda  ...       Medium  Regularly busy  Regularly busy
# 23           0         Soda  ...       Medium  Regularly busy    Busiest days
# 37           0         Soda  ...       Medium  Regularly busy      Least busy
# 58           0         Soda  ...       Medium  Regularly busy      Least busy
# 75           0         Soda  ...       Medium  Regularly busy      Least busy
# 78           0         Soda  ...       Medium  Regularly busy    Busiest days
# 95           0         Soda  ...       Medium  Regularly busy  Regularly busy
# 130          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 132          0         Soda  ...       Medium  Regularly busy    Busiest days
# 140          0         Soda  ...       Medium  Regularly busy      Least busy
# 155          0         Soda  ...       Medium  Regularly busy      Least busy
# 164          0         Soda  ...       Medium      Least busy      Least busy
# 174          0         Soda  ...       Medium  Regularly busy    Busiest days
# 197          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 238          0         Soda  ...       Medium  Regularly busy    Busiest days
# 261          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 264          0         Soda  ...       Medium     Busiest day    Busiest days
# 271          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 275          0         Soda  ...       Medium  Regularly busy    Busiest days
# 289          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 306          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 307          0         Soda  ...       Medium      Least busy      Least busy
# 316          0         Soda  ...       Medium  Regularly busy    Busiest days
# 328          0         Soda  ...       Medium  Regularly busy    Busiest days
# 357          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 358          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 391          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 443          0         Soda  ...       Medium      Least busy      Least busy
# 452          0         Soda  ...       Medium  Regularly busy  Regularly busy
# 462          0         Soda  ...       Medium  Regularly busy  Regularly busy
#
#     busiest_period_of_day max_number_of_orders      loyalty_flag  avg_spend  \
# 0          Average orders                   10      New customer   6.367797
# 23            Most orders                   27  Regular customer   6.356287
# 37            Most orders                   24  Regular customer   7.656790
# 58            Most orders                   19  Regular customer   6.441221
# 75            Most orders                    3      New customer   9.385714
# 78            Most orders                   58    Loyal customer   7.149730
# 95            Most orders                    3      New customer  10.006250
# 130           Most orders                    4      New customer   4.550000
# 132           Most orders                    5      New customer   6.030769
# 140           Most orders                    5      New customer   6.590909
# 155        Average orders                   10      New customer   7.814035
# 164           Most orders                    7      New customer  10.366667
# 174           Most orders                    5      New customer   7.021053
# 197        Average orders                    7      New customer   8.251852
# 238        Average orders                   28  Regular customer   6.607122
# 261           Most orders                   29  Regular customer   6.291954
# 264        Average orders                    6      New customer   7.869748
# 271           Most orders                    3      New customer   7.372222
# 275           Most orders                   22  Regular customer   6.308108
# 289           Most orders                    6      New customer  11.466667
# 306           Most orders                    9      New customer   9.369355
# 307           Most orders                    9      New customer   6.887500
# 316           Most orders                   35  Regular customer   7.278571
# 328           Most orders                   13  Regular customer   7.433784
# 357           Most orders                   44    Loyal customer   7.950181
# 358        Average orders                   68    Loyal customer   5.332484
# 391           Most orders                   99    Loyal customer   8.174396
# 443           Most orders                   10      New customer   7.340541
# 452        Average orders                   12  Regular customer   6.378723
# 462         Fewest orders                    5      New customer   9.120000
#
#        spend_flag median_d_s_p_o         frequency_flag
# 0     Low spender           20.5  Non-frequent customer
# 23    Low spender            8.0      Frequent customer
# 37    Low spender            7.0      Frequent customer
# 58    Low spender           11.5       Regular customer
# 75    Low spender           19.0       Regular customer
# 78    Low spender            4.0      Frequent customer
# 95   High spender            4.0      Frequent customer
# 130   Low spender           10.0      Frequent customer
# 132   Low spender           21.0  Non-frequent customer
# 140   Low spender            7.0      Frequent customer
# 155   Low spender           25.5  Non-frequent customer
# 164  High spender           12.0       Regular customer
# 174   Low spender           27.0  Non-frequent customer
# 197   Low spender            6.0      Frequent customer
# 238   Low spender            7.0      Frequent customer
# 261   Low spender           10.0      Frequent customer
# 264   Low spender            6.0      Frequent customer
# 271   Low spender           30.0  Non-frequent customer
# 275   Low spender            7.0      Frequent customer
# 289  High spender           30.0  Non-frequent customer
# 306   Low spender            7.0      Frequent customer
# 307   Low spender           27.0  Non-frequent customer
# 316   Low spender            7.0      Frequent customer
# 328   Low spender           27.0  Non-frequent customer
# 357   Low spender            7.0      Frequent customer
# 358   Low spender            6.0      Frequent customer
# 391   Low spender            2.0      Frequent customer
# 443   Low spender           21.0  Non-frequent customer
# 452   Low spender           14.0       Regular customer
# 462   Low spender           22.0  Non-frequent customer
#
# [30 rows x 23 columns]

# %%
# Unable to determine why 5 values are NaN. Since it's a minuscule amount will just ignore them
# First Check shape of dataframe

# %%
df_ords_prods_merged_2.shape
# Out:
# (32404859, 23)

# %%
# Drop all rows where the value in the specified column(s) are NaNs
df_ords_prods_merged_2 = df_ords_prods_merged_2.dropna(subset=['median_d_s_p_o', 'frequency_flag'], how = 'all')

# %%
# Check output
df_ords_prods_merged_2.shape
# Out:
# (32404854, 23)

# %%
# Check again if column frequency_flag has ok values
df_ords_prods_merged_2['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# Name: frequency_flag, dtype: int64

# %%
# STEP 9 Export to pickle
df_ords_prods_merged_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_3.pkl'))
